# %%
# imports
import pandas as pd
import yfinance as yf

#set tickers and dates
tickers_list = ['SPY', 'AAPL', 'GOOG', 'NVDA', 'TSLA', 'META', 'MSFT', 'DIS', 'AMZN']
start_date = '2015-1-1'
end_date = '2024-5-5'


# Fetch the data
data = yf.download(tickers_list, start_date , end_date)['Adj Close']


# Print to check
print(data.tail(10))
# Out:
# [*********************100%%**********************]  9 of 9 completed
# Ticker            AAPL        AMZN         DIS        GOOG        META  \
# Date
# 2024-04-22  165.839996  177.229996  111.989998  157.949997  481.730011
# 2024-04-23  166.899994  179.539993  113.709999  159.919998  496.100006
# 2024-04-24  169.020004  176.589996  113.919998  161.100006  493.500000
# 2024-04-25  169.889999  173.669998  112.769997  157.949997  441.380005
# 2024-04-26  169.300003  179.619995  112.730003  173.690002  443.290009
# 2024-04-29  173.500000  180.960007  112.080002  167.899994  432.619995
# 2024-04-30  170.330002  175.000000  111.099998  164.639999  430.170013
# 2024-05-01  169.300003  179.000000  110.480003  165.570007  439.190002
# 2024-05-02  173.029999  184.720001  112.620003  168.460007  441.679993
# 2024-05-03  183.380005  186.210007  113.660004  168.990005  451.959991
#
# Ticker            MSFT        NVDA         SPY        TSLA
# Date
# 2024-04-22  400.959991  795.179993  499.720001  142.050003
# 2024-04-23  407.570007  824.229980  505.649994  144.679993
# 2024-04-24  409.059998  796.770020  505.410004  162.130005
# 2024-04-25  399.040009  826.320007  503.489990  170.179993
# 2024-04-26  406.320007  877.349976  508.260010  168.289993
# 2024-04-29  402.250000  877.570007  510.059998  194.050003
# 2024-04-30  389.329987  864.020020  501.980011  183.279999
# 2024-05-01  394.940002  830.409973  500.350006  179.990005
# 2024-05-02  397.839996  858.169983  505.029999  180.009995
# 2024-05-03  406.660004  887.890015  511.290009  181.190002

# %%
# Plot all the close prices
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Returns", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Cumulative Returns', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 ((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
#       4 # Show the legend
# ----> 5 plt.legend()
#       7 # Define the label for the title of the figure
#       8 plt.title("Returns", fontsize=16)
#
# NameError: name 'plt' is not defined

# %%
# show nulls
## shows when coin was created
### do not drop nulls since then data will only go back to when most recent crypto hit the market
data.isnull().sum()
# Out:
# Ticker
# AAPL    0
# AMZN    0
# DIS     0
# GOOG    0
# META    0
# MSFT    0
# NVDA    0
# SPY     0
# TSLA    0
# dtype: int64

# %%
#Save 
data.to_csv('stock_data.csv')
