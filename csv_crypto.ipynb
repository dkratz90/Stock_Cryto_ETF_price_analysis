# %%
# imports
import pandas as pd
import yfinance as yf

#set tickers and dates
tickers_list = ['BTC-USD', 'ETH-USD', 'BNB-USD', 'ADA-USD', 'XRP-USD', 'SOL-USD', 'DOT-USD', 'LTC-USD', 'LINK-USD', 'BCH-USD']
start_date = '2015-1-1'
end_date = '2024-5-5'


# Fetch the data
data = yf.download(tickers_list, start_date , end_date)['Adj Close']


# Print to check
print(data.tail(10))
# Out:
# [*********************100%%**********************]  10 of 10 completed
# Ticker       ADA-USD     BCH-USD     BNB-USD       BTC-USD   DOT-USD  \
# Date
# 2024-04-25  0.471020  478.724457  614.005005  64481.707031  6.862369
# 2024-04-26  0.462729  482.437103  597.705444  63755.320312  6.758217
# 2024-04-27  0.467032  477.419830  595.720520  63419.140625  6.798635
# 2024-04-28  0.460474  470.621277  600.071167  63113.230469  6.723606
# 2024-04-29  0.457365  465.610016  592.831238  63841.121094  6.591733
# 2024-04-30  0.440812  434.157166  578.488037  60636.855469  6.422238
# 2024-05-01  0.449866  424.038635  561.408203  58254.011719  6.883043
# 2024-05-02  0.458282  429.969849  560.526733  59123.433594  7.285116
# 2024-05-03  0.467544  453.345551  587.010437  62889.835938  7.255101
# 2024-05-04  0.463577  463.508820  585.846558  63891.472656  7.127060
#
# Ticker          ETH-USD   LINK-USD    LTC-USD     SOL-USD   XRP-USD
# Date
# 2024-04-25  3156.509521  14.599360  83.798103  144.892120  0.525512
# 2024-04-26  3130.164795  14.480972  87.992081  139.104340  0.526112
# 2024-04-27  3252.168213  14.252130  83.882629  141.289169  0.517775
# 2024-04-28  3262.774658  13.808069  83.952034  137.856415  0.510377
# 2024-04-29  3215.428955  14.073785  83.515251  137.776657  0.515432
# 2024-04-30  3012.286865  13.133521  79.495316  126.962708  0.500065
# 2024-05-01  2969.784668  13.344388  80.095863  134.627975  0.517000
# 2024-05-02  2988.168457  13.595815  80.122772  137.814484  0.518329
# 2024-05-03  3103.541992  14.109475  81.930138  143.772552  0.531894
# 2024-05-04  3117.576416  14.318272  81.687035  146.135056  0.530405

# %%
# Plot all the close prices
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Returns", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Cumulative Returns', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 ((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
#       4 # Show the legend
# ----> 5 plt.legend()
#       7 # Define the label for the title of the figure
#       8 plt.title("Returns", fontsize=16)
#
# NameError: name 'plt' is not defined

# %%
# show nulls
## shows when coin was created
### do not drop nulls since then data will only go back to when most recent crypto hit the market
data.isnull().sum()
# Out:
# Ticker
# ADA-USD     1043
# BCH-USD     1043
# BNB-USD     1043
# BTC-USD        0
# DOT-USD     2058
# ETH-USD     1043
# LINK-USD    1043
# LTC-USD        0
# SOL-USD     1926
# XRP-USD     1043
# dtype: int64

# %%
#Save 
data.to_csv('crypto_data.csv')
